# %% [markdown]
# # **Lab 7 : Titanic Survival Prediction**
# ##### Created By: CMPUT 175 Content Development Team

# %% [markdown]
# In this lab, you will predict the survival of Titanic passengers using Python and the scikit-learn library. This lab will introduce you to basic data manipulation techniques, training a classification model, and evaluating its performance. By the end of the assignment, you will have a hands-on understanding of preprocessing data, applying machine learning algorithms, and interpreting the results.

# %% [markdown]
# # Instructions
# Each question corresponds to a code cell. Follow the instructions carefully and complete the missing parts.

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Q1: Load the Dataset
# Load the dataset titanic.csv using appropriate data structure. Do not use any other library like csv, pandas, numpy, etc.
#
# Print the total number of rows (including the header) in the dataset.

# %%
# TODO: ADD YOUR CODE HERE
with open('titanic.csv', 'r') as file:
    data = file.read().splitlines()
    print(f'Total rows in dataset: {len(data)}')
# Out:
# Total rows in dataset: 892

# %% [markdown]
# ### Q2: Print the Column Names
# Print all the column names from the dataset.

# %%
# TODO: ADD YOUR CODE HERE
col_names = data.pop(0).split(',')
print(f'Column Names: {col_names}')
# Out:
# Column Names: ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %% [markdown]
# ### Q3: Print the First 25 Rows
# Print the first 25 rows of the dataset, excluding the header.

# %%
# TODO: ADD YOUR CODE HERE
data = [item.split(',') for item in data]

for i in range(25):
    print(data[i])
# Out:
# ['1', '0', '3', '"Braund', ' Mr. Owen Harris"', 'male', '22', '1', '0', 'A/5 21171', '7.25', '', 'S']
# ['2', '1', '1', '"Cumings', ' Mrs. John Bradley (Florence Briggs Thayer)"', 'female', '38', '1', '0', 'PC 17599', '71.2833', 'C85', 'C']
# ['3', '1', '3', '"Heikkinen', ' Miss. Laina"', 'female', '26', '0', '0', 'STON/O2. 3101282', '7.925', '', 'S']
# ['4', '1', '1', '"Futrelle', ' Mrs. Jacques Heath (Lily May Peel)"', 'female', '35', '1', '0', '113803', '53.1', 'C123', 'S']
# ['5', '0', '3', '"Allen', ' Mr. William Henry"', 'male', '35', '0', '0', '373450', '8.05', '', 'S']
# ['6', '0', '3', '"Moran', ' Mr. James"', 'male', '', '0', '0', '330877', '8.4583', '', 'Q']
# ['7', '0', '1', '"McCarthy', ' Mr. Timothy J"', 'male', '54', '0', '0', '17463', '51.8625', 'E46', 'S']
# ['8', '0', '3', '"Palsson', ' Master. Gosta Leonard"', 'male', '2', '3', '1', '349909', '21.075', '', 'S']
# ...

# %% [markdown]
# ### Q4: Filter the Dataset
# Remove all unnecessary columns and retain only the relevant columns: Survived, Pclass, Sex, and Age. Print the new header and the first 10 rows of the filtered dataset.

# %%
# TODO: ADD YOUR CODE HERE
print("Filtered Header:\n['Survived', 'Pclass', 'Sex', 'Age']\n")

filtered = []
for person in data:
    filtered.append([person[1], person[2], person[5], person[6]])

for i in range(10):
    print(filtered[i])
# Out:
# Filtered Header:
# ['Survived', 'Pclass', 'Sex', 'Age']
#
# ['0', '3', 'male', '22']
# ['1', '1', 'female', '38']
# ['1', '3', 'female', '26']
# ['1', '1', 'female', '35']
# ['0', '3', 'male', '35']
# ['0', '3', 'male', '']
# ['0', '1', 'male', '54']
# ['0', '3', 'male', '2']
# ['1', '3', 'female', '27']
# ['1', '2', 'female', '14']

# %% [markdown]
# ### Q5: Process Missing and Categorical Data

# %% [markdown]
# ### Q5a: Convert the Sex Column to Numeric
# Replace the values in the Sex column:
# *   Convert "male" to 0.
# *   Convert "female" to 1.
#
# Print the first 10 rows of the dataset after this conversion.

# %%
# TODO: ADD YOUR CODE HERE
print("First 10 rows after converting 'Sex' to numeric:\n")

for person in filtered:
    if person[2] == 'male':
        person[2] = 0
    elif person[2] == 'female':
        person[2] = 1

for i in range(10):
    print(filtered[i])
# Out:
# First 10 rows after converting 'Sex' to numeric:
#
# ['0', '3', 0, '22']
# ['1', '1', 1, '38']
# ['1', '3', 1, '26']
# ['1', '1', 1, '35']
# ['0', '3', 0, '35']
# ['0', '3', 0, '']
# ['0', '1', 0, '54']
# ['0', '3', 0, '2']
# ['1', '3', 1, '27']
# ['1', '2', 1, '14']

# %% [markdown]
# ### Q5b: Handle Missing Age Values
# Remove the rows with empty Age values. Print the first 10 rows of the dataset after handling missing values.

# %%
# TODO: ADD YOUR CODE HERE
print(f"Number of rows before dropping missing 'Age' values: {len(filtered)}")

# for person in filtered:
#     if person[3] == '':
#         filtered.remove(person)
#     elif person[3] == ' ':
#         filtered.remove(person)

new_filtered = []
for person in filtered:
    if person[3] != '':
        new_filtered.append(person)




print(f"Number of rows before dropping missing 'Age' values: {len(new_filtered)}")
print("First 10 rows after handling missing 'Age' values: ")

for i in range(10):
    print(new_filtered[i])
# Out:
# Number of rows before dropping missing 'Age' values: 891
# Number of rows before dropping missing 'Age' values: 714
# First 10 rows after handling missing 'Age' values:
# ['0', '3', 0, '22']
# ['1', '1', 1, '38']
# ['1', '3', 1, '26']
# ['1', '1', 1, '35']
# ['0', '3', 0, '35']
# ['0', '1', 0, '54']
# ['0', '3', 0, '2']
# ['1', '3', 1, '27']
# ['1', '2', 1, '14']
# ['1', '3', 1, '4']

# %% [markdown]
# ### Q6: Split Features and Labels
# Separate the dataset into features (Pclass, Sex, Age) and labels (Survived). Print the first 10 rows of each.

# %%
# TODO: ADD YOUR CODE HERE
features = [item[1:4] for item in new_filtered]
labels = [item[0] for item in new_filtered]

print("Features: ")
for i in range(10):
    print(features[i])

print("\nLabels: ")
for i in range(10):
    print(labels[i])
# Out:
# Features:
# ['3', 0, '22']
# ['1', 1, '38']
# ['3', 1, '26']
# ['1', 1, '35']
# ['3', 0, '35']
# ['1', 0, '54']
# ['3', 0, '2']
# ['3', 1, '27']
# ['2', 1, '14']
# ['3', 1, '4']
#
# Labels:
# 0
# 1
# 1
# 1
# 0
# 0
# 0
# 1
# 1
# 1

# %% [markdown]
# ### Q7: Split Data for Training and Testing
# Split the features and labels into training and testing sets (80%-20%). Print the number of rows in the training and testing sets.

# %%
# TODO: ADD YOUR CODE HERE
x_train, x_test, y_train, y_test = train_test_split(
    features, labels,
    test_size=0.2,
    random_state=42
)

print(f'Training set size: {len(x_train)}')
print(f'Testing set size: {len(x_test)}')
# Out:
# Training set size: 571
# Testing set size: 143

# %% [markdown]
# ### Q8: Train a Decision Tree Classifier
# Train a DecisionTreeClassifier on the training data. Print a message indicating the training is complete.

# %%
# TODO: ADD YOUR CODE HERE

model = DecisionTreeClassifier(random_state=42)
model.fit(x_train, y_train)

print('Model training complete.')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
#       1 # TODO: ADD YOUR CODE HERE
#       3 model = DecisionTreeClassifier(random_state=42)
# ----> 4 model.fit(x_train, y_train)
#       6 print('Model training complete.')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# ...

# %% [markdown]
# ### Q9: Evaluate the Model
# Use the test set to calculate model's accuracy and print it.

# %%
# TODO: ADD YOUR CODE HERE
y_pred = model.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)

print(f'Model Accuacy: {round(accuracy, 2)}')
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[82], line 2
#       1 # TODO: ADD YOUR CODE HERE
# ----> 2 y_pred = model.predict(x_test)
#       4 accuracy = accuracy_score(y_test, y_pred)
#       6 print(f'Model Accuacy: {round(accuracy, 2)}')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\tree\_classes.py:532, in BaseDecisionTree.predict(self, X, check_input)
#     509 def predict(self, X, check_input=True):
#     510     """Predict class or regression value for X.
#     511
#     512     For a classification model, the predicted class for each sample in X is
#    (...)    530         The predicted classes, or the predict values.
#     531     """
# --> 532     check_is_fitted(self)
#     533     X = self._validate_X_predict(X, check_input)
# ...
